# %%
# Regression
from sklearn.linear_model import LinearRegression, Ridge, ElasticNet, Lasso
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, BaggingRegressor, ExtraTreesRegressor, GradientBoostingRegressor, RandomForestRegressor, VotingRegressor
from sklearn.metrics import mean_squared_error as mse

import xgboost as xgb
import lightgbm as lgb
import catboost as cat

from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np

# %%
import os
print(os.listdir('../input'))
# Out:
# ['std-drug']

# %%
train = pd.read_csv("../input/std-drug/train.csv")
test = pd.read_csv("../input/std-drug/test.csv")

# %%
min_rating = train.effectiveness_rating.min()
max_rating = train.effectiveness_rating.max()

def scale_rating(rating):
    # Sacling from (1,10) to (0,5) and then replacing 0,1,2 in ratings with 0 (poor) and 3,4,5 with 1 (good).
    rating -= min_rating
    rating = rating/(max_rating - 1)
    rating *= 3
    rating = int(round(rating,0))
    return rating

train['new_effect_score'] = train.effectiveness_rating.apply(scale_rating)
test['new_effect_score'] = test.effectiveness_rating.apply(scale_rating)

# %%
from nltk.corpus import wordnet

def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
    
import string
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer

def clean_text(text):
    # lower text
    text = text.lower()
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    # remove words that contain numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
    # remove stop words
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop]
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
    # pos tag text
    pos_tags = pos_tag(text)
    # lemmatize text
    text = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
    # remove words with only one letter
    text = [t for t in text if len(t) > 1]
    # join all
    text = " ".join(text)
    return(text)

# clean text data
train["review_by_patient"] = train["review_by_patient"].apply(lambda x: clean_text(x))

# %%
test["review_by_patient"] = test["review_by_patient"].apply(lambda x: clean_text(x))

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
train["sentiments"] = train["review_by_patient"].apply(lambda x: sid.polarity_scores(x))
test["sentiments"] = test["review_by_patient"].apply(lambda x: sid.polarity_scores(x))

# reviews_df = pd.concat([reviews_df.drop(['sentiments'], axis=1), reviews_df['sentiments'].apply(pd.Series)], axis=1)

# %%
train.sentiments[0]
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# train['neg_sentiment'] = train.sentiments.apply(lambda x:round(x['neg']))
train['pos_sentiment'] = train.sentiments.apply(lambda x:round(x['pos']))
# train['neu_sentimant'] = train.sentiments.apply(lambda x:round(x['neu']))

test['neg_sentiment'] = test.sentiments.apply(lambda x:round(x['neg']))
test['pos_sentiment'] = test.sentiments.apply(lambda x:round(x['pos']))
test['neu_sentimant'] = test.sentiments.apply(lambda x:round(x['neu']))

# %%
train.head()
# Out:
#    patient_id              name_of_drug             use_case_for_drug  \
# 0      206461                 Valsartan  Left Ventricular Dysfunction
# 1       95260                Guanfacine                          ADHD
# 2       92703                    Lybrel                 Birth Control
# 3       35696  Buprenorphine / naloxone             Opiate Dependence
# 4      155963                    Cialis  Benign Prostatic Hyperplasia
#
#                                    review_by_patient  effectiveness_rating  \
# 0  side effect take combination bystolic mg fish oil                     9
# 1  son halfway fourth week intuniv become concern...                     8
# 2  use take another oral contraceptive pill cycle...                     5
# 3  suboxone completely turn life around feel heal...                     9
# 4  day start work rock hard erection however expe...                     2
#
#   drug_approved_by_UIC  number_of_times_prescribed  base_score  \
# 0            20-May-12                          27    8.022969
# 1            27-Apr-10                         192    7.858458
# 2            14-Dec-09                          17    6.341969
# 3            27-Nov-16                          37    6.590176
# 4            28-Nov-15                          43    6.144782
#
#    new_effect_score                                         sentiments  \
# 0                 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1                 2  {'neg': 0.035, 'neu': 0.767, 'pos': 0.198, 'co...
# 2                 1  {'neg': 0.044, 'neu': 0.822, 'pos': 0.134, 'co...
# 3                 3  {'neg': 0.119, 'neu': 0.582, 'pos': 0.299, 'co...
# 4                 0  {'neg': 0.265, 'neu': 0.593, 'pos': 0.143, 'co...
#
#    neg_sentiment  pos_sentiment  neu_sentimant
# 0              0              0              1
# 1              0              0              1
# 2              0              0              1
# 3              0              0              1
# 4              0              0              1

# %%
feat = train.columns.to_list()
target='base_score'
delete = ['patient_id','name_of_drug','use_case_for_drug','review_by_patient','drug_approved_by_UIC',target,'sentiments','neg_sentiment','neu_sentimant']
for i in delete:
    feat.remove(i)

# %%
train.corr()
# Out:
#                             patient_id  effectiveness_rating  \
# patient_id                    1.000000              0.018803
# effectiveness_rating          0.018803              1.000000
# number_of_times_prescribed    0.017499              0.242224
# base_score                    0.010924              0.412301
# new_effect_score              0.017318              0.980980
# neg_sentiment                -0.000675             -0.090975
# pos_sentiment                 0.001931              0.087138
# neu_sentimant                -0.006971             -0.002984
#
#                             number_of_times_prescribed  base_score  \
# patient_id                                    0.017499    0.010924
# effectiveness_rating                          0.242224    0.412301
# number_of_times_prescribed                    1.000000    0.134295
# base_score                                    0.134295    1.000000
# new_effect_score                              0.240236    0.422065
# neg_sentiment                                -0.006126   -0.047388
# pos_sentiment                                -0.016375    0.045599
# neu_sentimant                                -0.038959   -0.003828
#
#                             new_effect_score  neg_sentiment  pos_sentiment  \
# patient_id                          0.017318      -0.000675       0.001931
# effectiveness_rating                0.980980      -0.090975       0.087138
# number_of_times_prescribed          0.240236      -0.006126      -0.016375
# base_score                          0.422065      -0.047388       0.045599
# new_effect_score                    1.000000      -0.088844       0.085392
# neg_sentiment                      -0.088844       1.000000      -0.018395
# pos_sentiment                       0.085392      -0.018395       1.000000
# neu_sentimant                      -0.003546      -0.277303      -0.386478
#
#                             neu_sentimant
# patient_id                      -0.006971
# effectiveness_rating            -0.002984
# number_of_times_prescribed      -0.038959
# base_score                      -0.003828
# new_effect_score                -0.003546
# neg_sentiment                   -0.277303
# pos_sentiment                   -0.386478
# neu_sentimant                    1.000000

# %%
# from sklearn.preprocessing import MinMaxScaler
# scalar = MinMaxScaler()
# X=scalar.fit_transform(train[feat])
# Y = train[target].values.reshape(-1,1)

# %%
def baseliner(X,Y):
    print("Baseliner Models(All)")
    eval_dict = {}
    models = [
#         KNeighborsRegressor(), GaussianNB(), 
        lgb.LGBMRegressor(), ExtraTreesRegressor(), xgb.XGBRegressor(objective='reg:squarederror'), 
        cat.CatBoostRegressor(verbose=0), GradientBoostingRegressor(), RandomForestRegressor(), 
        LinearRegression(), DecisionTreeRegressor(), ExtraTreeRegressor(), AdaBoostRegressor(), 
#         BaggingRegressor(), ElasticNet(), Lasso(), Ridge(),SVR(),
        ]  

    print("sklearn Model Name  \t  rmse")
    print("--" * 50)
    x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=42)
    for i in models:
        model = i
        model.fit(x_train,y_train)
        y_pred = model.predict(x_test)
        model_name =str(i).split("(")[0]
        result=np.sqrt(mse(y_test,y_pred))
        print(f"{model_name} \t {result}")
baseliner(train[feat],train[target])
# Out:
# Baseliner Models(All)
# sklearn Model Name  	  rmse
# ----------------------------------------------------------------------------------------------------
# LGBMRegressor 	 0.20095215267981803
# ExtraTreesRegressor 	 0.19108259884969508
# XGBRegressor 	 0.1036262445166938
# <catboost.core.CatBoostRegressor object at 0x7f3334ca8c18> 	 0.1450782188846404
# GradientBoostingRegressor 	 0.5546314616331539
# RandomForestRegressor 	 0.17014818973376164
# LinearRegression 	 1.443646954203997
# DecisionTreeRegressor 	 0.17394073455557982
# ExtraTreeRegressor 	 0.23479032671114147
# AdaBoostRegressor 	 1.1280279294272682

# %% [markdown]
# ## Hyperopt for Better Parameters

# %%
from hyperopt import hp
import numpy as np
from sklearn.metrics import mean_squared_error


# XGB parameters
xgb_reg_params = {
    'learning_rate':    hp.choice('learning_rate',    np.arange(0.05, 0.31, 0.05)),
    'max_depth':        hp.choice('max_depth',        np.arange(5, 16, 1, dtype=int)),
    'min_child_weight': hp.choice('min_child_weight', np.arange(1, 8, 1, dtype=int)),
    'colsample_bytree': hp.choice('colsample_bytree', np.arange(0.3, 0.8, 0.1)),
    'subsample':        hp.uniform('subsample', 0.8, 1),
    'n_estimators':     500,
}
xgb_fit_params = {
    'eval_metric': 'rmse',
    'early_stopping_rounds': 10,
    'verbose': False
}
xgb_para = dict()
xgb_para['reg_params'] = xgb_reg_params
xgb_para['fit_params'] = xgb_fit_params
xgb_para['loss_func' ] = lambda y, pred: np.sqrt(mean_squared_error(y, pred))

# LightGBM parameters
lgb_reg_params = {
    'learning_rate':    hp.choice('learning_rate',    np.arange(0.05, 0.31, 0.05)),
    'max_depth':        hp.choice('max_depth',        np.arange(5, 16, 1, dtype=int)),
    'min_child_weight': hp.choice('min_child_weight', np.arange(1, 8, 1, dtype=int)),
    'colsample_bytree': hp.choice('colsample_bytree', np.arange(0.3, 0.8, 0.1)),
    'subsample':        hp.uniform('subsample', 0.8, 1),
    'n_estimators':     100,
}
lgb_fit_params = {
    'eval_metric': 'l2',
    'early_stopping_rounds': 10,
    'verbose': False
}
lgb_para = dict()
lgb_para['reg_params'] = lgb_reg_params
lgb_para['fit_params'] = lgb_fit_params
lgb_para['loss_func' ] = lambda y, pred: np.sqrt(mean_squared_error(y, pred))


# CatBoost parameters
ctb_reg_params = {
    'learning_rate':     hp.choice('learning_rate',     np.arange(0.05, 0.31, 0.05)),
    'max_depth':         hp.choice('max_depth',         np.arange(5, 16, 1, dtype=int)),
    'colsample_bylevel': hp.choice('colsample_bylevel', np.arange(0.3, 0.8, 0.1)),
    'n_estimators':      100,
    'eval_metric':       'RMSE',
}
ctb_fit_params = {
    'early_stopping_rounds': 10,
    'verbose': False
}
ctb_para = dict()
ctb_para['reg_params'] = ctb_reg_params
ctb_para['fit_params'] = ctb_fit_params
ctb_para['loss_func' ] = lambda y, pred: np.sqrt(mean_squared_error(y, pred))

# %%
import lightgbm as lgb
import xgboost as xgb
import catboost as ctb
from hyperopt import fmin, tpe, STATUS_OK, STATUS_FAIL, Trials


class HPOpt(object):

    def __init__(self, x_train, x_test, y_train, y_test):
        self.x_train = x_train
        self.x_test  = x_test
        self.y_train = y_train
        self.y_test  = y_test

    def process(self, fn_name, space, trials, algo, max_evals):
        fn = getattr(self, fn_name)
        try:
            result = fmin(fn=fn, space=space, algo=algo, max_evals=max_evals, trials=trials)
        except Exception as e:
            return {'status': STATUS_FAIL,
                    'exception': str(e)}
        return result, trials

    def xgb_reg(self, para):
        reg = xgb.XGBRegressor(**para['reg_params'])
        return self.train_reg(reg, para)

    def lgb_reg(self, para):
        reg = lgb.LGBMRegressor(**para['reg_params'])
        return self.train_reg(reg, para)

    def ctb_reg(self, para):
        reg = ctb.CatBoostRegressor(**para['reg_params'])
        return self.train_reg(reg, para)

    def train_reg(self, reg, para):
        reg.fit(self.x_train, self.y_train,
                eval_set=[(self.x_train, self.y_train), (self.x_test, self.y_test)],
                **para['fit_params'])
        pred = reg.predict(self.x_test)
        loss = para['loss_func'](self.y_test, pred)
        return {'loss': loss, 'status': STATUS_OK}

# %%
x_train, x_test, y_train, y_test = train_test_split(train[feat],train[target], test_size=0.3, random_state=42)
obj = HPOpt(x_train, x_test, y_train, y_test)
xgb_opt = obj.process(fn_name='xgb_reg', space=xgb_para, trials=Trials(), algo=tpe.suggest, max_evals=200)
lgb_opt = obj.process(fn_name='lgb_reg', space=lgb_para, trials=Trials(), algo=tpe.suggest, max_evals=200)
ctb_opt = obj.process(fn_name='ctb_reg', space=ctb_para, trials=Trials(), algo=tpe.suggest, max_evals=200)
# Out:
#  94%|█████████▍| 189/200 [09:38<00:41,  3.79s/trial, best loss: 0.06063439703523072]

# %% [markdown]
# ## Stacking

# %%
from sklearn.ensemble import StackingRegressor
# Creating First Layer
base_learners = [
    ('lgbm',lgb.LGBMRegressor(boosting_type='gbdt',
                        num_leaves=300,
                        max_depth=16,
                        learning_rate = 0.5,
                        n_estimators=400,
                         subsample_for_bin=200000,
#                          class_weight=,
#                          min_split_gain=0.01,
#                          min_child_weight=0.1,
                         objective=None,
                         min_child_samples=20,
                         subsample=1.0,
                         subsample_freq=0,
                         colsample_bytree=1.0,
                         reg_alpha=0.0,
                         reg_lambda=0.0,
                         random_state=None,
                         n_jobs=-1,
                         silent=True
                        )),
]
# Initializating Stacking Regressor with the meta lerner
reg = StackingRegressor(estimators=base_learners,final_estimator=xgb.XGBRegressor(objective='reg:squarederror',n_estimators=500,max_depth=8,learning_rate=0.25,colsample_bytree=0.7,min_child_weight=1,subsample=0.8862306230110487))
train_X, test_X, train_y, test_y = train_test_split(train[feat],train[target], test_size=0.3, random_state=42)
reg.fit(train_X,train_y)
y_pred = reg.predict(test_X)
print(np.sqrt(mse(test_y,y_pred)))

# %%
lgbm = lgb.LGBMRegressor(boosting_type='gbdt',
                        num_leaves=300,
                        max_depth=16,
                        learning_rate = 0.5,
                        n_estimators=400,
                         subsample_for_bin=200000,
#                          class_weight=,
#                          min_split_gain=0.01,
#                          min_child_weight=0.1,
                         objective=None,
                         min_child_samples=20,
                         subsample=1.0,
                         subsample_freq=0,
                         colsample_bytree=1.0,
                         reg_alpha=0.0,
                         reg_lambda=0.0,
                         random_state=None,
                         n_jobs=-1,
                         silent=True
                        )
lgbm.fit(train[feat],train[target])

# %%
train_X, test_X, train_y, test_y = train_test_split(train[feat],train[target], test_size=0.3, random_state=42)
y_pred = lgbm.predict(test_X)
print(np.sqrt(mse(test_y,y_pred)))

# %%
train_X, test_X, train_y, test_y = train_test_split(train[feat],train[target], test_size=0.3, random_state=42)

my_model = xgb.XGBRegressor(objective='reg:squarederror',n_estimators=500,max_depth=8,learning_rate=0.25,colsample_bytree=0.7,min_child_weight=1,subsample=0.8862306230110487)
my_model.fit(train[feat],train[target],early_stopping_rounds=10, eval_set=[(test_X, test_y)], verbose=1)
y_pred = my_model.predict(test_X)
print(np.sqrt(mse(test_y,y_pred)))
# Out:
# [0]	validation_0-rmse:4.81132
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:3.68830
# [2]	validation_0-rmse:2.84086
# [3]	validation_0-rmse:2.21006
# [4]	validation_0-rmse:1.75853
# [5]	validation_0-rmse:1.42552
# [6]	validation_0-rmse:1.19061
# [7]	validation_0-rmse:1.03607
# [8]	validation_0-rmse:0.86784
# [9]	validation_0-rmse:0.77743
# [10]	validation_0-rmse:0.71657
# [11]	validation_0-rmse:0.67998
# [12]	validation_0-rmse:0.63143
# [13]	validation_0-rmse:0.57519
# [14]	validation_0-rmse:0.53912
# [15]	validation_0-rmse:0.53299
# [16]	validation_0-rmse:0.48636
# [17]	validation_0-rmse:0.48416
# [18]	validation_0-rmse:0.45582
# [19]	validation_0-rmse:0.45482
# [20]	validation_0-rmse:0.40984
# [21]	validation_0-rmse:0.40297
# [22]	validation_0-rmse:0.38836
# [23]	validation_0-rmse:0.38827
# [24]	validation_0-rmse:0.38778
# [25]	validation_0-rmse:0.37122
# [26]	validation_0-rmse:0.36517
# [27]	validation_0-rmse:0.35717
# [28]	validation_0-rmse:0.35687
# [29]	validation_0-rmse:0.35685
# [30]	validation_0-rmse:0.32575
# [31]	validation_0-rmse:0.32560
# [32]	validation_0-rmse:0.31654
# [33]	validation_0-rmse:0.31647
# [34]	validation_0-rmse:0.29003
# [35]	validation_0-rmse:0.28603
# [36]	validation_0-rmse:0.28597
# [37]	validation_0-rmse:0.27421
# [38]	validation_0-rmse:0.27417
# [39]	validation_0-rmse:0.27416
# [40]	validation_0-rmse:0.25320
# [41]	validation_0-rmse:0.25319
# [42]	validation_0-rmse:0.24803
# [43]	validation_0-rmse:0.24208
# [44]	validation_0-rmse:0.24206
# [45]	validation_0-rmse:0.24205
# [46]	validation_0-rmse:0.24205
# [47]	validation_0-rmse:0.24205
# [48]	validation_0-rmse:0.24206
# [49]	validation_0-rmse:0.23632
# [50]	validation_0-rmse:0.22617
# [51]	validation_0-rmse:0.22616
# [52]	validation_0-rmse:0.21294
# [53]	validation_0-rmse:0.20491
# [54]	validation_0-rmse:0.20166
# [55]	validation_0-rmse:0.20166
# [56]	validation_0-rmse:0.20165
# [57]	validation_0-rmse:0.20001
# [58]	validation_0-rmse:0.19092
# [59]	validation_0-rmse:0.18322
# [60]	validation_0-rmse:0.18321
# [61]	validation_0-rmse:0.18321
# [62]	validation_0-rmse:0.17576
# [63]	validation_0-rmse:0.17136
# [64]	validation_0-rmse:0.16828
# [65]	validation_0-rmse:0.16325
# [66]	validation_0-rmse:0.16324
# [67]	validation_0-rmse:0.16324
# [68]	validation_0-rmse:0.16325
# [69]	validation_0-rmse:0.15847
# [70]	validation_0-rmse:0.15074
# [71]	validation_0-rmse:0.15074
# [72]	validation_0-rmse:0.14980
# [73]	validation_0-rmse:0.14980
# [74]	validation_0-rmse:0.14815
# [75]	validation_0-rmse:0.14500
# [76]	validation_0-rmse:0.14313
# [77]	validation_0-rmse:0.13916
# [78]	validation_0-rmse:0.13681
# [79]	validation_0-rmse:0.13680
# [80]	validation_0-rmse:0.13680
# [81]	validation_0-rmse:0.13679
# [82]	validation_0-rmse:0.13561
# [83]	validation_0-rmse:0.13560
# [84]	validation_0-rmse:0.13496
# [85]	validation_0-rmse:0.12574
# [86]	validation_0-rmse:0.12573
# [87]	validation_0-rmse:0.12574
# [88]	validation_0-rmse:0.12220
# [89]	validation_0-rmse:0.12176
# [90]	validation_0-rmse:0.12176
# [91]	validation_0-rmse:0.11929
# [92]	validation_0-rmse:0.11751
# [93]	validation_0-rmse:0.11675
# [94]	validation_0-rmse:0.11597
# [95]	validation_0-rmse:0.11597
# [96]	validation_0-rmse:0.11597
# [97]	validation_0-rmse:0.11596
# [98]	validation_0-rmse:0.11545
# [99]	validation_0-rmse:0.11431
# [100]	validation_0-rmse:0.11092
# [101]	validation_0-rmse:0.10672
# [102]	validation_0-rmse:0.10672
# [103]	validation_0-rmse:0.10629
# [104]	validation_0-rmse:0.10439
# [105]	validation_0-rmse:0.10312
# [106]	validation_0-rmse:0.10244
# [107]	validation_0-rmse:0.10244
# [108]	validation_0-rmse:0.10184
# [109]	validation_0-rmse:0.10183
# [110]	validation_0-rmse:0.10183
# [111]	validation_0-rmse:0.10183
# [112]	validation_0-rmse:0.10138
# [113]	validation_0-rmse:0.10138
# [114]	validation_0-rmse:0.09989
# [115]	validation_0-rmse:0.09989
# [116]	validation_0-rmse:0.09989
# [117]	validation_0-rmse:0.09989
# [118]	validation_0-rmse:0.09939
# [119]	validation_0-rmse:0.09897
# [120]	validation_0-rmse:0.09749
# [121]	validation_0-rmse:0.09749
# [122]	validation_0-rmse:0.09596
# [123]	validation_0-rmse:0.09595
# [124]	validation_0-rmse:0.09528
# [125]	validation_0-rmse:0.09475
# [126]	validation_0-rmse:0.09475
# [127]	validation_0-rmse:0.09208
# [128]	validation_0-rmse:0.08616
# [129]	validation_0-rmse:0.08534
# [130]	validation_0-rmse:0.08427
# [131]	validation_0-rmse:0.08426
# [132]	validation_0-rmse:0.08425
# [133]	validation_0-rmse:0.08399
# [134]	validation_0-rmse:0.08376
# [135]	validation_0-rmse:0.08347
# [136]	validation_0-rmse:0.08340
# [137]	validation_0-rmse:0.08290
# [138]	validation_0-rmse:0.08290
# [139]	validation_0-rmse:0.08289
# [140]	validation_0-rmse:0.08289
# [141]	validation_0-rmse:0.08278
# [142]	validation_0-rmse:0.08278
# [143]	validation_0-rmse:0.08258
# [144]	validation_0-rmse:0.08257
# [145]	validation_0-rmse:0.08069
# [146]	validation_0-rmse:0.08069
# [147]	validation_0-rmse:0.08069
# [148]	validation_0-rmse:0.08044
# [149]	validation_0-rmse:0.07996
# [150]	validation_0-rmse:0.07996
# [151]	validation_0-rmse:0.07874
# [152]	validation_0-rmse:0.07874
# [153]	validation_0-rmse:0.07750
# [154]	validation_0-rmse:0.07750
# [155]	validation_0-rmse:0.07689
# [156]	validation_0-rmse:0.07689
# [157]	validation_0-rmse:0.07623
# [158]	validation_0-rmse:0.07604
# [159]	validation_0-rmse:0.07576
# [160]	validation_0-rmse:0.07472
# [161]	validation_0-rmse:0.07456
# [162]	validation_0-rmse:0.07439
# [163]	validation_0-rmse:0.07439
# [164]	validation_0-rmse:0.07401
# [165]	validation_0-rmse:0.07382
# [166]	validation_0-rmse:0.07369
# [167]	validation_0-rmse:0.07369
# [168]	validation_0-rmse:0.07321
# [169]	validation_0-rmse:0.07322
# [170]	validation_0-rmse:0.07300
# [171]	validation_0-rmse:0.07300
# [172]	validation_0-rmse:0.07288
# [173]	validation_0-rmse:0.06679
# [174]	validation_0-rmse:0.06679
# [175]	validation_0-rmse:0.06554
# [176]	validation_0-rmse:0.06193
# [177]	validation_0-rmse:0.06193
# [178]	validation_0-rmse:0.06125
# [179]	validation_0-rmse:0.06096
# [180]	validation_0-rmse:0.06096
# [181]	validation_0-rmse:0.06080
# [182]	validation_0-rmse:0.06074
# [183]	validation_0-rmse:0.06067
# [184]	validation_0-rmse:0.06067
# [185]	validation_0-rmse:0.06037
# [186]	validation_0-rmse:0.06030
# [187]	validation_0-rmse:0.06007
# [188]	validation_0-rmse:0.06007
# [189]	validation_0-rmse:0.06007
# [190]	validation_0-rmse:0.05993
# [191]	validation_0-rmse:0.05993
# [192]	validation_0-rmse:0.05980
# [193]	validation_0-rmse:0.05971
# [194]	validation_0-rmse:0.05938
# [195]	validation_0-rmse:0.05935
# [196]	validation_0-rmse:0.05935
# [197]	validation_0-rmse:0.05936
# [198]	validation_0-rmse:0.05932
# [199]	validation_0-rmse:0.05923
# [200]	validation_0-rmse:0.05867
# [201]	validation_0-rmse:0.05867
# [202]	validation_0-rmse:0.05862
# [203]	validation_0-rmse:0.05856
# [204]	validation_0-rmse:0.05826
# [205]	validation_0-rmse:0.05802
# [206]	validation_0-rmse:0.05799
# [207]	validation_0-rmse:0.05799
# [208]	validation_0-rmse:0.05799
# [209]	validation_0-rmse:0.05788
# [210]	validation_0-rmse:0.05778
# [211]	validation_0-rmse:0.05778
# [212]	validation_0-rmse:0.05774
# [213]	validation_0-rmse:0.05723
# [214]	validation_0-rmse:0.05714
# [215]	validation_0-rmse:0.05713
# [216]	validation_0-rmse:0.05411
# [217]	validation_0-rmse:0.05406
# [218]	validation_0-rmse:0.05407
# [219]	validation_0-rmse:0.05293
# [220]	validation_0-rmse:0.05079
# [221]	validation_0-rmse:0.05075
# [222]	validation_0-rmse:0.05075
# [223]	validation_0-rmse:0.05075
# [224]	validation_0-rmse:0.05043
# [225]	validation_0-rmse:0.05041
# [226]	validation_0-rmse:0.04956
# [227]	validation_0-rmse:0.04956
# [228]	validation_0-rmse:0.04899
# [229]	validation_0-rmse:0.04381
# [230]	validation_0-rmse:0.04381
# [231]	validation_0-rmse:0.04372
# [232]	validation_0-rmse:0.04350
# [233]	validation_0-rmse:0.04327
# [234]	validation_0-rmse:0.04324
# [235]	validation_0-rmse:0.04174
# [236]	validation_0-rmse:0.03936
# [237]	validation_0-rmse:0.03936
# [238]	validation_0-rmse:0.03937
# [239]	validation_0-rmse:0.03820
# [240]	validation_0-rmse:0.03805
# [241]	validation_0-rmse:0.03805
# [242]	validation_0-rmse:0.03801
# [243]	validation_0-rmse:0.03801
# [244]	validation_0-rmse:0.03801
# [245]	validation_0-rmse:0.03801
# [246]	validation_0-rmse:0.03630
# [247]	validation_0-rmse:0.03616
# [248]	validation_0-rmse:0.03519
# [249]	validation_0-rmse:0.03456
# [250]	validation_0-rmse:0.03456
# [251]	validation_0-rmse:0.03455
# [252]	validation_0-rmse:0.03308
# [253]	validation_0-rmse:0.03181
# [254]	validation_0-rmse:0.03048
# [255]	validation_0-rmse:0.03048
# [256]	validation_0-rmse:0.03048
# [257]	validation_0-rmse:0.03048
# [258]	validation_0-rmse:0.03048
# [259]	validation_0-rmse:0.03028
# [260]	validation_0-rmse:0.03025
# [261]	validation_0-rmse:0.03025
# [262]	validation_0-rmse:0.03015
# [263]	validation_0-rmse:0.03015
# [264]	validation_0-rmse:0.03015
# [265]	validation_0-rmse:0.03009
# [266]	validation_0-rmse:0.03004
# [267]	validation_0-rmse:0.03004
# [268]	validation_0-rmse:0.03004
# [269]	validation_0-rmse:0.02861
# [270]	validation_0-rmse:0.02859
# [271]	validation_0-rmse:0.02857
# [272]	validation_0-rmse:0.02857
# [273]	validation_0-rmse:0.02857
# [274]	validation_0-rmse:0.02857
# [275]	validation_0-rmse:0.02854
# [276]	validation_0-rmse:0.02727
# [277]	validation_0-rmse:0.02725
# [278]	validation_0-rmse:0.02726
# [279]	validation_0-rmse:0.02726
# [280]	validation_0-rmse:0.02726
# [281]	validation_0-rmse:0.02726
# [282]	validation_0-rmse:0.02724
# [283]	validation_0-rmse:0.02724
# [284]	validation_0-rmse:0.02723
# [285]	validation_0-rmse:0.02646
# [286]	validation_0-rmse:0.02646
# [287]	validation_0-rmse:0.02646
# [288]	validation_0-rmse:0.02645
# [289]	validation_0-rmse:0.02645
# [290]	validation_0-rmse:0.02645
# [291]	validation_0-rmse:0.02645
# [292]	validation_0-rmse:0.02645
# [293]	validation_0-rmse:0.02521
# [294]	validation_0-rmse:0.02521
# [295]	validation_0-rmse:0.02521
# [296]	validation_0-rmse:0.02521
# [297]	validation_0-rmse:0.02470
# [298]	validation_0-rmse:0.02402
# [299]	validation_0-rmse:0.02401
# [300]	validation_0-rmse:0.02398
# [301]	validation_0-rmse:0.02398
# [302]	validation_0-rmse:0.02398
# [303]	validation_0-rmse:0.02303
# [304]	validation_0-rmse:0.02299
# [305]	validation_0-rmse:0.02291
# [306]	validation_0-rmse:0.02291
# [307]	validation_0-rmse:0.02282
# [308]	validation_0-rmse:0.02282
# [309]	validation_0-rmse:0.02282
# [310]	validation_0-rmse:0.02269
# [311]	validation_0-rmse:0.02268
# [312]	validation_0-rmse:0.02268
# [313]	validation_0-rmse:0.02149
# [314]	validation_0-rmse:0.02144
# [315]	validation_0-rmse:0.02079
# [316]	validation_0-rmse:0.02001
# [317]	validation_0-rmse:0.01941
# [318]	validation_0-rmse:0.01940
# [319]	validation_0-rmse:0.01871
# [320]	validation_0-rmse:0.01864
# [321]	validation_0-rmse:0.01863
# [322]	validation_0-rmse:0.01863
# [323]	validation_0-rmse:0.01862
# [324]	validation_0-rmse:0.01861
# [325]	validation_0-rmse:0.01852
# [326]	validation_0-rmse:0.01850
# [327]	validation_0-rmse:0.01793
# [328]	validation_0-rmse:0.01730
# [329]	validation_0-rmse:0.01729
# [330]	validation_0-rmse:0.01720
# [331]	validation_0-rmse:0.01720
# [332]	validation_0-rmse:0.01683
# [333]	validation_0-rmse:0.01641
# [334]	validation_0-rmse:0.01638
# [335]	validation_0-rmse:0.01598
# [336]	validation_0-rmse:0.01594
# [337]	validation_0-rmse:0.01593
# [338]	validation_0-rmse:0.01594
# [339]	validation_0-rmse:0.01592
# [340]	validation_0-rmse:0.01592
# [341]	validation_0-rmse:0.01592
# [342]	validation_0-rmse:0.01573
# [343]	validation_0-rmse:0.01573
# [344]	validation_0-rmse:0.01573
# [345]	validation_0-rmse:0.01573
# [346]	validation_0-rmse:0.01572
# [347]	validation_0-rmse:0.01573
# [348]	validation_0-rmse:0.01573
# [349]	validation_0-rmse:0.01536
# [350]	validation_0-rmse:0.01536
# [351]	validation_0-rmse:0.01511
# [352]	validation_0-rmse:0.01511
# [353]	validation_0-rmse:0.01494
# [354]	validation_0-rmse:0.01494
# [355]	validation_0-rmse:0.01491
# [356]	validation_0-rmse:0.01491
# [357]	validation_0-rmse:0.01490
# [358]	validation_0-rmse:0.01490
# [359]	validation_0-rmse:0.01484
# [360]	validation_0-rmse:0.01484
# [361]	validation_0-rmse:0.01481
# [362]	validation_0-rmse:0.01481
# [363]	validation_0-rmse:0.01481
# [364]	validation_0-rmse:0.01480
# [365]	validation_0-rmse:0.01478
# [366]	validation_0-rmse:0.01478
# [367]	validation_0-rmse:0.01478
# [368]	validation_0-rmse:0.01477
# [369]	validation_0-rmse:0.01477
# [370]	validation_0-rmse:0.01476
# [371]	validation_0-rmse:0.01433
# [372]	validation_0-rmse:0.01433
# [373]	validation_0-rmse:0.01433
# [374]	validation_0-rmse:0.01433
# [375]	validation_0-rmse:0.01433
# [376]	validation_0-rmse:0.01432
# [377]	validation_0-rmse:0.01430
# [378]	validation_0-rmse:0.01430
# [379]	validation_0-rmse:0.01430
# [380]	validation_0-rmse:0.01430
# [381]	validation_0-rmse:0.01428
# [382]	validation_0-rmse:0.01422
# [383]	validation_0-rmse:0.01374
# [384]	validation_0-rmse:0.01364
# [385]	validation_0-rmse:0.01364
# [386]	validation_0-rmse:0.01286
# [387]	validation_0-rmse:0.01285
# [388]	validation_0-rmse:0.01285
# [389]	validation_0-rmse:0.01281
# [390]	validation_0-rmse:0.01281
# [391]	validation_0-rmse:0.01226
# [392]	validation_0-rmse:0.01226
# [393]	validation_0-rmse:0.01226
# [394]	validation_0-rmse:0.01193
# [395]	validation_0-rmse:0.01184
# [396]	validation_0-rmse:0.01172
# [397]	validation_0-rmse:0.01172
# [398]	validation_0-rmse:0.01142
# [399]	validation_0-rmse:0.01142
# [400]	validation_0-rmse:0.01091
# [401]	validation_0-rmse:0.01027
# [402]	validation_0-rmse:0.01006
# [403]	validation_0-rmse:0.01002
# [404]	validation_0-rmse:0.01002
# [405]	validation_0-rmse:0.01001
# [406]	validation_0-rmse:0.00996
# [407]	validation_0-rmse:0.00996
# [408]	validation_0-rmse:0.00962
# [409]	validation_0-rmse:0.00922
# [410]	validation_0-rmse:0.00869
# [411]	validation_0-rmse:0.00839
# [412]	validation_0-rmse:0.00839
# [413]	validation_0-rmse:0.00839
# [414]	validation_0-rmse:0.00839
# [415]	validation_0-rmse:0.00839
# [416]	validation_0-rmse:0.00839
# [417]	validation_0-rmse:0.00839
# [418]	validation_0-rmse:0.00809
# [419]	validation_0-rmse:0.00809
# [420]	validation_0-rmse:0.00805
# [421]	validation_0-rmse:0.00791
# [422]	validation_0-rmse:0.00791
# [423]	validation_0-rmse:0.00771
# [424]	validation_0-rmse:0.00771
# [425]	validation_0-rmse:0.00771
# [426]	validation_0-rmse:0.00746
# [427]	validation_0-rmse:0.00734
# [428]	validation_0-rmse:0.00734
# [429]	validation_0-rmse:0.00732
# [430]	validation_0-rmse:0.00731
# [431]	validation_0-rmse:0.00729
# [432]	validation_0-rmse:0.00729
# [433]	validation_0-rmse:0.00717
# [434]	validation_0-rmse:0.00709
# [435]	validation_0-rmse:0.00685
# [436]	validation_0-rmse:0.00668
# [437]	validation_0-rmse:0.00668
# [438]	validation_0-rmse:0.00668
# [439]	validation_0-rmse:0.00667
# [440]	validation_0-rmse:0.00660
# [441]	validation_0-rmse:0.00661
# [442]	validation_0-rmse:0.00660
# [443]	validation_0-rmse:0.00647
# [444]	validation_0-rmse:0.00632
# [445]	validation_0-rmse:0.00632
# [446]	validation_0-rmse:0.00630
# [447]	validation_0-rmse:0.00628
# [448]	validation_0-rmse:0.00627
# [449]	validation_0-rmse:0.00627
# [450]	validation_0-rmse:0.00627
# [451]	validation_0-rmse:0.00612
# [452]	validation_0-rmse:0.00612
# [453]	validation_0-rmse:0.00612
# [454]	validation_0-rmse:0.00612
# [455]	validation_0-rmse:0.00612
# [456]	validation_0-rmse:0.00612
# [457]	validation_0-rmse:0.00591
# [458]	validation_0-rmse:0.00591
# [459]	validation_0-rmse:0.00590
# [460]	validation_0-rmse:0.00577
# [461]	validation_0-rmse:0.00577
# [462]	validation_0-rmse:0.00577
# [463]	validation_0-rmse:0.00577
# [464]	validation_0-rmse:0.00575
# [465]	validation_0-rmse:0.00575
# [466]	validation_0-rmse:0.00574
# [467]	validation_0-rmse:0.00574
# [468]	validation_0-rmse:0.00574
# [469]	validation_0-rmse:0.00574
# [470]	validation_0-rmse:0.00573
# [471]	validation_0-rmse:0.00568
# [472]	validation_0-rmse:0.00565
# [473]	validation_0-rmse:0.00552
# [474]	validation_0-rmse:0.00553
# [475]	validation_0-rmse:0.00552
# [476]	validation_0-rmse:0.00543
# [477]	validation_0-rmse:0.00543
# [478]	validation_0-rmse:0.00543
# [479]	validation_0-rmse:0.00537
# [480]	validation_0-rmse:0.00537
# [481]	validation_0-rmse:0.00537
# [482]	validation_0-rmse:0.00518
# [483]	validation_0-rmse:0.00510
# [484]	validation_0-rmse:0.00510
# [485]	validation_0-rmse:0.00508
# [486]	validation_0-rmse:0.00507
# [487]	validation_0-rmse:0.00499
# [488]	validation_0-rmse:0.00496
# [489]	validation_0-rmse:0.00495
# [490]	validation_0-rmse:0.00495
# [491]	validation_0-rmse:0.00471
# [492]	validation_0-rmse:0.00471
# [493]	validation_0-rmse:0.00471
# [494]	validation_0-rmse:0.00471
# [495]	validation_0-rmse:0.00460
# [496]	validation_0-rmse:0.00460
# [497]	validation_0-rmse:0.00460
# [498]	validation_0-rmse:0.00449
# [499]	validation_0-rmse:0.00447
# 0.004474878373703329

# %%
y_pred = my_model.predict(test[feat])
ans=[]
for i in range(len(y_pred)):
    ans.append(round(y_pred[i],2))
sub = test['patient_id']
sub = pd.DataFrame(sub)
sub['base_score']=ans

# %%
#Creating Link in Kaggle
from IPython.display import HTML
import pandas as pd
import numpy as np
import base64

def create_download_link(df, title = "Download CSV file", filename = "std_20.csv"):  
    csv = df.to_csv(index=False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(sub)
# Out:
# <a download="std_20.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
